# %%
#Import packages
import scipy.io.wavfile
import matplotlib.pyplot as plt
import scipy.fftpack as scf
from scipy import signal
import numpy as np
import os
import pandas as pd
from mpl_toolkits import mplot3d
path='C:/Users/arne/Documents/School/Thesis'; #Change this to directory that stores the data
os.chdir(path)

# %%
#Plot soundwave
[T,test_data]=scipy.io.wavfile.read('Test.wav', mmap=False); #T: sample rate
N=len(test_data); #number of samples
t=np.linspace(0,N/T, num=N) #time
plt.plot(t,test_data)
plt.title('Soundwave')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.tight_layout() #Ensures axis doesn't get cut off when saving
plt.show()
#plt.savefig('Test')

# %%
yf = np.fft.fft(test_data)
n = np.fft.fftfreq(N)
# 1/T = frequency

plt.ylabel("Amplitude")
plt.xlabel("Frequency [Hz]")
plt.title("Fourier diagram")
plt.plot(n[:N//2], np.abs(yf)[:N//2]*1/N)  # 1/N is a normalization factor, fft is symmetrical, so only half needs to be plotted
plt.tight_layout() #Ensures axis doesn't get cut off when saving
plt.show()
#plt.savefig('Test_fourier')

# %%
len(test_data)
# Out:
# 2097108

# %%
plt.scatter(t[:1000000], n[:1000000], c=abs(test_data[:1000000]))
plt.tight_layout()
plt.show()
